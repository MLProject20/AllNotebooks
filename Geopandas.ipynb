# %%
import geopandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-fc7d1d298f0c> in <module>
# ----> 1 import geopandas
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
sys.path.append('C:\\WINDOWS\\system32')

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\padu\\Downloads',
#  'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcPy',
#  'C:\\Users\\padu\\AppData\\Local\\ESRI\\conda\\envs\\arcgispro-py3-clone3\\python37.zip',
#  'C:\\Users\\padu\\AppData\\Local\\ESRI\\conda\\envs\\arcgispro-py3-clone3\\DLLs',
#  'C:\\Users\\padu\\AppData\\Local\\ESRI\\conda\\envs\\arcgispro-py3-clone3\\lib',
#  'C:\\Users\\padu\\AppData\\Local\\ESRI\\conda\\envs\\arcgispro-py3-clone3',
#  '',
#  'C:\\Users\\padu\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'C:\\Users\\padu\\AppData\\Local\\ESRI\\conda\\envs\\arcgispro-py3-clone3\\lib\\site-packages',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin',
#  'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcToolbox\\Scripts',
#  'C:\\Users\\padu\\AppData\\Local\\ESRI\\conda\\envs\\arcgispro-py3-clone3\\lib\\site-packages\\Pillow_SIMD-5.3.0.post1-py3.7-win-amd64.egg',
#  'C:\\Users\\padu\\AppData\\Local\\ESRI\\conda\\envs\\arcgispro-py3-clone3\\lib\\site-packages\\future-0.18.2-py3.7.egg',
# ...

# %%
path = ['C:\\WINDOWS\\system32',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\python37.zip',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\DLLs',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3',
 '',
 'C:\\Users\\padu\\AppData\\Roaming\\Python\\Python37\\site-packages',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\win32',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\win32\\lib',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\Pythonwin',
 'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\IPython\\extensions',
 'C:\\Users\\padu\\.ipython']

# %%
for row in path:
    sys.path.append(row)

# %%
sys.path
# Out:
# ['C:\\Users\\padu\\Downloads',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\python37.zip',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\DLLs',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3',
#  '',
#  'C:\\Users\\padu\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\padu\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\padu\\.ipython']

# %%
import pandas as pd

# %%
pd.read_excel('Housing Violations 2010-Present.xlsx', sheet_name= '2011' )
# Out:
#         Date Case Created Case Type        Case Origin   Case Number  \
# 0              2011-05-19  Nuisance                NaN   20110022158
# 1              2011-05-19  Nuisance                NaN   20110022158
# 2              2011-05-19  Nuisance                NaN   20110022158
# 3              2011-05-19  Nuisance                NaN   20110022158
# 4              2011-05-19  Nuisance                NaN   20110022158
# ...                   ...       ...                ...           ...
# 1020069        2011-12-30    Zoning  Field Observation  Z20110055422
# 1020070        2011-12-30    Zoning  Field Observation  Z20110055422
# 1020071        2011-12-30    Zoning  Field Observation  Z20110055422
# 1020072        2011-12-30    Zoning  Field Observation  Z20110055422
# 1020073        2011-12-30    Zoning  Field Observation  Z20110055422
#
#         Case Status          Property Address Unit Number Property City  \
# ...
